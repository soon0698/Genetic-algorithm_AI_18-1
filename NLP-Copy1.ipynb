# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint
import pandas as pd
from collections import namedtuple
from sklearn.utils import shuffle
# %matplotlib inline

kkma = Kkma()
pprint(kkma.sentences(u'1차 산업과 2차 산업을 기반으로 한 서비스 관련 업종들이 이에 해당한다. 각국의 경제 상황에 따라 차이는 있겠지만 보통 가장 큰 비중을 차지하는 것은 운송업과 상업, 금융업 등이다. 선진국에서는 이 3차 산업의 비중이 극대화된 나머지 기존 산업을 분류하는 것이 점점 무의미해져서 새로운 분류도 모색하고 있는 형국이다.운송업관광업상업(국제무역)서비스업운수통신금융보험유통기타연구개발'))
sentences = kkma.sentences(u'1차 산업과 2차 산업을 기반으로 한 서비스 관련 업종들이 이에 해당한다. 각국의 경제 상황에 따라 차이는 있겠지만 보통 가장 큰 비중을 차지하는 것은 운송업과 상업, 금융업 등이다. 선진국에서는 이 3차 산업의 비중이 극대화된 나머지 기존 산업을 분류하는 것이 점점 무의미해져서 새로운 분류도 모색하고 있는 형국이다.운송업관광업상업(국제무역)서비스업운수통신금융보험유통기타연구개발')
# 금융 문서에 대한 문장 분리 예시
# Out:
# ['1차 산업과 2차 산업을 기반으로 한 서비스 관련 업종들이 이에 해당한다.',
#  '각국의 경제 상황에 따라 차이는 있겠지만 보통 가장 큰 비중을 차지하는 것은 운송업과 상업, 금융업 등이다.',
#  '선진국에서는 이 3차 산업의 비중이 극대화된 나머지 기존 산업을 분류하는 것이 점점 무의미 해져서 새로운 분류도 모색하고 있는 형국이다.',
#  '운송업 관광업 상업( 국제무역) 서비스업 운수통신금융보험 유통 기타 연구개발']

# %%
math = kkma.sentences('공통미적분학선형대수학미분방정식[18]해석학수학과수학교육과전공과목미분기하학[19]정수론[20]집합론위상수학[21]현대대수학(추상대수학)[22]수학 비전공자들을 위한 과목경제수학(경제학과, 경영학과, 상업정보교육과)공업수학(공과대학, 공업교육계열, 기술교육과)군론(물리학과, 물리교육과, 화학과, 화학교육과)수리물리학(물리학과, 물리교육과, 화학과, 화학교육과)이산수학[23](컴퓨터공학과, 컴퓨터교육과)수치해석[24](공과대학, 공업교육계열)"고급이산수학조합론그래프이론수치해석대수학미분기하학대수기하학실해석학고급정수론대수적정수론해석적정수론편미분방정식확률론')
pprint(math)
# 수학 문서에 대한 문장 분리 예시
# Out:
# ['공통 미적분학 선형대수학 미분 방정식 [18] 해석학 수학과수학교육과 전공과목 미분 기하학 [19] 정수론 [20] 집합론 위상수학 '
#  '[21] 현대대수학( 추상대수학) [22] 수학 비전 공자들을 위한 과목 경제수학( 경제학과, 경영학과, 상업정보 교육과) 공업수학( '
#  '공과 대학, 공업교육 계열, 기술 교육과) 군론( 물리학과, 물리 교육과, 화학과, 화학교육과) 수리 물리학( 물리학과, 물리 교육과, '
#  '화학과, 화학교육과) 이산수학 [23]( 컴퓨터 공학과, 컴퓨터 교육과) 수치해석 [24]( 공과 대학, 공업교육 계열)" 고급 '
#  '이산수학조합론 그래프이론 수치해석대수학 미분 기하학 대수 기하학 실해석 학 고급 정수론 대수적 정수론해석적 정수론 편 미분 방정식 확률론']

# %%
for sentence in sentences:
    print(kkma.nouns(sentence))
# 금융 문서의 문장에 대한 '명사 분리' 예시
# Out:
# ['1', '1차', '차', '산업과', '2', '2차', '산업', '기반', '서비스', '관련', '업종', '해당']
# ['각국', '경제', '상황', '차이', '보통', '비중', '차지', '운송업', '상업', '금융업', '등']
# ['선진국', '3', '3차', '차', '산업', '비중', '극대화', '나머지', '기존', '분류', '무의미', '분류도', '모색', '형국']
# ['운송업', '관광업', '상업', '국제', '국제무역', '무역', '서비스', '서비스업', '업', '운수', '운수통신금융보험', '통신', '금융', '보험', '유통', '기타', '연구', '연구개발', '개발']

# %%
for sentence in math:
    print(kkma.nouns(sentence))
# 수학 문서의 문장에 대한 '명사 분리' 예시
# Out:
# ['공통', '미적분', '미적분학', '학', '선형', '선형대수학', '대수학', '미분', '방정식', '18', '해석학', '수학과', '수학과수학교육', '수학', '교육', '전공', '전공과목', '과목', '기하학', '19', '정수론', '20', '집합론', '위상', '위상수학', '21', '현대', '현대대수학', '추상', '추상대수학', '22', '비전', '공자', '경제', '경제수학', '경제학과', '학과', '경영학과', '상업', '상업정보', '정보', '교육과', '공업', '공업수학', '공', '대학', '공업교육', '계열', '기술', '군론', '물리', '물리학과', '화학과', '화학', '화학교육', '수리', '물리학', '이산', '이산수학', '23', '컴퓨터', '공학과', '수치', '수치해석', '해석', '24', '고급', '이산수학조합', '조합', '그래프', '그래프이론', '이론', '수치해석대수학', '대수', '실', '실해석', '정수론해석', '편', '확률론']

# %%
for sentence in sentences:
    print(kkma.pos(sentence))
#형태소 태깅 예시
# Out:
# [('1', 'NR'), ('차', 'NNM'), ('산업과', 'NNG'), ('2', 'NR'), ('차', 'NNM'), ('산업', 'NNG'), ('을', 'JKO'), ('기반', 'NNG'), ('으로', 'JKM'), ('한', 'MDN'), ('서비스', 'NNG'), ('관련', 'NNG'), ('업종', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('이에', 'MAG'), ('해당', 'NNG'), ('하', 'XSV'), ('ㄴ다', 'EFN'), ('.', 'SF')]
# [('각국', 'NNG'), ('의', 'JKG'), ('경제', 'NNG'), ('상황', 'NNG'), ('에', 'JKM'), ('따르', 'VV'), ('아', 'ECS'), ('차이', 'NNG'), ('는', 'JX'), ('있', 'VV'), ('겠', 'EPT'), ('지만', 'ECE'), ('보통', 'NNG'), ('가장', 'MAG'), ('크', 'VA'), ('ㄴ', 'ETD'), ('비중', 'NNG'), ('을', 'JKO'), ('차지', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('운송업', 'NNG'), ('과', 'JC'), ('상업', 'NNG'), (',', 'SP'), ('금융업', 'NNG'), ('등', 'NNB'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF')]
# [('선진국', 'NNG'), ('에서', 'JKM'), ('는', 'JX'), ('이', 'MDT'), ('3', 'NR'), ('차', 'NNM'), ('산업', 'NNG'), ('의', 'JKG'), ('비중', 'NNG'), ('이', 'JKS'), ('극대화', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('나머지', 'NNG'), ('기존', 'NNG'), ('산업', 'NNG'), ('을', 'JKO'), ('분류', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('점점', 'MAG'), ('무의미', 'NNG'), ('해지', 'VV'), ('어서', 'ECD'), ('새롭', 'VA'), ('ㄴ', 'ETD'), ('분류도', 'NNG'), ('모색', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('형국', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF')]
# [('운송업', 'NNG'), ('관광업', 'NNG'), ('상업', 'NNG'), ('(', 'SS'), ('국제', 'NNG'), ('무역', 'NNG'), (')', 'SS'), ('서비스업', 'NNG'), ('운수', 'NNG'), ('통신', 'NNG'), ('금융', 'NNG'), ('보험', 'NNG'), ('유통', 'NNG'), ('기타', 'NNG'), ('연구', 'NNG'), ('개발', 'NNG')]

# %%
finance = pd.read_csv('./si_manage.csv', 'utf8', engine='python')
finance['topic'] = pd.Series(0, index=finance.index)
finance
#금융 문서에 대한 데이터 로드 및 살펴보기
# Out:
#                                                  text  topic
# 0   "기업은 이윤 추구를 목적으로 경영 활동을 수행하는 개별 경제의 단위이며, 경영은 ...      0
# 1   '계획을 세워 사업을 해나감'은 계획을 세움(planning)과 사업을 해나감(ex...      0
# 2   "다시 말하면, 경영이라는 활동은 정해져 있는 목적을 어떻게 달성할 것인가에 대한 ...      0
# 3   "첫째 단계는 1차 목적의 결정이다. 영업종류·영업규모·자본규모 등의 항구적·기본적...      0
# 4   "계속적 사업을 경제적으로 해 나가기 위한 작업상 조직'은 경영(영어: busine...      0
# 5   "개별경제는 그 경제목적에 따라 생산경제체(生産經濟體)와 소비경제체(消費經濟體)로 ...      0
# 6   "이 2가지의 가치를 일정 기간을 두고 보면 총수익과 총지출이 되며, 경영은 생산활...      0
# 7   "경영에 있어서의 합리성이란 바로 이러한 의미의 것으로서, 이것은 다른 일반적인 합...      0
# 8   "공업화가 진전되고 각 분야의 조직활동의 규모가 확대되고, 특히 기업조직의 제반현상...      0
# 9   "첫째, 사람의 특질에 관한 것으로 이는 모든 경영체가 인간의 행위를 떠나서는 존재...      0
# 10  "둘째, 경영이 현대수준에 있어 조직적 현상이므로 인간의 유기적 종합행위로서의 조직...      0
# 11  "셋째, 경영기능에 관한 기본적 이해가 있어야 한다. 경영기능이란 경영자가 작업자와...      0
# 12  "그런데 근자에는 보다 고차적인 전문기능으로서 의사결정이라는 측면이 중요하다는 것이...      0
# 13  "넷째, 오늘의 경영은 전문지식을 구사하지 않으면 안 된다. 예를 들면 보다 생산능...      0
# 14  "다섯째, 오늘의 경영은 계량적 기초 위에서 논해져야 하며, 이를 위해서 많은 연구...      0
# 15  "여섯째, 현대경영은 현대기업의 환경여건을 잘 이해하지 못하면 그 기능을 원만하게 ...      0
# 16                                      선택성 원리(選擇性原理)      0
# 17  경영활동에 있어서는 많은 물적 자원과 인적 자원을 동원하고 이를 합리적으로 결합시켜...      0
# 18                                  (2) 적응성 원리(適應性原理)      0
# 19  "기업이 유지되고 발전하려면 그 기업자체가 소속되어 있는 산업 및 국민경제의 변화와...      0
# 20                                  (3) 창조성 원리(創造性原理)      0
# 21  경영자는 기업의 유지·발전을 위해서 창조적 활동을 계속하지 않으면 안 된다. 낡은 ...      0
# 22  선택성과 적응성과 창조성의 원리는 따로 따로 분리된 것이 아니고 서로 밀접한 관련성...      0
# 23  "경영이 특정의 목적에 대해 가장 합리적으로 접근하는 의식적 사회구성체를 가리키는 ...      0
# 24  "경영목적과 경영방침의 관계를 고찰해 보면 다음과 같다. 경영목적은 경영목표(obj...      0
# 25  "경영의 목적에 대해서는 개념의 체계화가 되지 못하고 있다. 즉 그것은 일반적으로 ...      0
# 26  "경영방침은 경영목적을 합리적·효율적으로 달성하기 위한 행동원리, 지배원칙이다. 즉...      0
# 27  "경영방침의 구분은 첫째 경영에 미치는 국면의 상이에서 기본방침(basic poli...      0
# 28  "둘째로 경영방침은 그의 실천성·구체성에 따라 기본방침과 집행방침(operative...      0
# 29  "초기 개인적 사기업(私企業) 시대에는 기업이 모두 개인에 의해 지배되고 운영되어 ...      0
# 30                              '기업의 사회적 책임'(CSR)의 자각      0
# 31                           이 부분의 본문은 기업의 사회적 책임입니다.      0
# 32  근대기업의 활동은 사회와 조화를 이루어야 한다. 사회적 이익과 기업의 이익이 함께 ...      0
# 33  "기업규모의 확대에 따라 다수 인간의 집단이 형성되면, 이것을 경영 또는 관리(管理...      0
# 34  "경영기능(經營機能)은 경영의 기능(영어: management function) 또...      0
# 35  경영의 기능을 의식적으로 찾아내어 그것을 과학화하고 관리제도를 수립하려고 한 것이 ...      0
# 36  테일러와 거의 같은 시대에 앙리 페이욜(H. Fayol)은 바로 이러한 점에서 경영...      0
# 37        "(1) 기술활동(technical activities) ― 생산제조, 가공"      0
# 38     "(2) 영업활동(commercial activities) ― 구매, 판매, 교환"      0
# 39        (3) 재무활동(financial activities) ― 자본의 조달과 운용      0
# 40        (4) 보전활동(security activities) ― 설비와 종업원의 보전      0
# 41  "(5) 회계활동(accounting activities) ― 재산목록, 대차대조표...      0

# %%
math = pd.read_csv('./si_stat.csv', 'utf8', engine='python')
math['topic'] = pd.Series(1, index=math.index)
math
#수학 문서에 대한 데이터 로드 및 살펴보기
# Out:
#                                                  text  topic
# 0   "단순한 평균 분산 등의 상투적인 분석 이외에, 모집단에서 어떤인자들이 있는지 뽑아...      1
# 1   "판별분석, 두 인자간의 상호관계에 대한 정준상관분석, 인자들의 숫자를 줄여 단순화...      1
# 2   "통계학은 컴퓨터 과학, 프로그래밍 언어, 선형대수학, 해석학, 분포론, 수치해석,...      1
# 3   "통계학과 사회과학의 발전에 따라 회귀분석, 인과분석 등과 같은 평가모형들이 발전되...      1
# 4   "특히 정보화사회와 빅데이터 시대를 맞아 다양한 사회정보의 수집·분석·활용을 담당하...      1
# 5   "사회조사분석사란 기업이나 정당, 지자체, 중앙정부 등 각종 단체가 필요로 하는 조...      1
# 6                                             통계학의 변화      1
# 7   현대에 들어와 데이터 과학자들로 구성된 통계 조직은 기관과 단체 그리고 기업의 수익...      1
# 8   " 수많은 데이터 가운데 의미 있는 데이터를 찾아냄으로써 더 나은 의사결정을 돕는 ...      1
# 9   "기업과 기관마다 부르는 이름은 다르지만, 생산·판매와 서비스 등 핵심 직무에서 영...      1
# 10  업계에서는 주요 데이터에 대한 분석과 통계가 이뤄지는 비즈니스인텔리전스(BI) 조직...      1
# 11  "전사자원관리(ERP) · 고객관계관리(CRM) · 생산관리시스템(MES) · 경영...      1
# 12  이러한 시대를 ‘빅 데이터’ 기술의 시대라고 하는데 미국의 유명 경제 출판 및 미디...      1
# 13  "포브스에 의하면 빅 데이터(Big Data) 데이터 마이닝이란 기존 데이터베이스 ...      1
# 14  "대한민국에서는 2000년부터 정보통신부의 산하단체로 사단법인 한국BI데이터마이닝학...      1
# 15  " 하지만 업계에 따르면, 미국과 영국, 일본 등 선진국들은 이미 빅 데이터를 다각...      1
# 16  그러나 한국은 정부와 일부 기업이 데이터과학자 양성을 위한 프로그램을 진행 중에 있...      1
# 17  모집단(population)은 관측 대상이 되는 전체 집단이다. 조사의 대상이 되는...      1
# 18  표본(sample)은 모 집단에서 일부만 조사한 것이다. 모집단에서 추출된 자료의 ...      1
# 19  "대푯값(representative value)은 어떤 데이터를 대표하는 값이다. ...      1
# 20            평균(mean)은 데이터를 모두 더한 후 데이터의 갯수로 나눈 값이다.      1
# 21  "중앙값(median)은 전체 데이터 중 가운데에 있는 수이다. 직원이 100명인 ...      1
# 22                          최빈값(mode)은 가장 자주 나오는 값이다.      1
# 23  기댓값(expected value)은 통계에서는 평균과 같다고 생각하면 된다. 가능...      1
# 24  "산포도(degree of scattering)는 자료가 흩어져 있는 정도를 나타낸...      1
# 25  "편차(deviation)는 관측값에서 평균 또는 중앙값을 뺀 것이다. 즉, 자료값...      1
# 26  "분산(variance)은 관측값에서 평균을 뺀 값을 제곱하고, 그것을 모두 더한 ...      1
# 27  표준 편차(standard deviation)는 분산을 제곱근한 것이다. 제곱해서 ...      1
# 28  "절대 편차(absolute deviation)는 관측값에서 평균 또는 중앙값을 빼...      1
# 29                   범위: 가장 큰 측정값에서 가장 작은 측정값을 뺀 값이다.      1
# ..                                                ...    ...
# 32  모 분산(population variance) σ2은 모집단의 분산이다. 관측값에서...      1
# 33  표본 분산(sample variance) s2은 표본의 분산이다. 관측값에서 표본 ...      1
# 34  모 표준 편차(population standard deviation) σ는 모 집단...      1
# 35  표본 표준 편차(sample standard deviation) s는 표본의 표준 ...      1
# 36  "평균 절대 편차(average absolute deviation 또는 mean a...      1
# 37  "중앙값 절대 편차(median absolute deviation)는 관측값에서 중...      1
# 38  최소 절대 편차(least absolute deviation)는 회귀 분석(regr...      1
# 39  전수조사 : 조사의 대상이 되는 자료 전체를 빠짐없이 조사하는 것이다.(모집단 전체...      1
# 40  표본조사 : 조사의 대상이 되는 자료의 일부만을 택하여 조사함으로써 전체를 추측하는...      1
# 41                                               측정수준      1
# 42  자료의 측정수준은 다음과 같이 분류된다. 측정수준에 따라 통계에 이용해야 할 요약 ...      1
# 43            분류 자료 : 수치로 측정이 불가능한 자료이다. 질적 자료라고도 한다.      1
# 44  "명목척도： 단순한 번호로 차례의 의미는 없다. (예: 전화번호, 등번호, 성별, ...      1
# 45   "순서척도(서열척도)： 순서가 의미를 가지는 번호. (예: 계급, 순위, 등급 등.)"      1
# 46             수량 자료 : 수치로 측정이 가능한 자료이다. 양적 자료라고도 한다.      1
# 47  "구간척도： 순서뿐만 아니라 그 간격에도 의미가 있으나, 0에 절대적인 의미는 없다...      1
# 48  "비율척도： 0을 기준으로 하는 절대적 척도로, 간격뿐만이 아니라 비율에도 의미가 ...      1
# 49                           변인: 연구의 대상이 되고 있는 일련의 개체      1
# 50  "독립 변인: 다른 변인에게 작용하거나 다른 변인을 예언하거나 설명해 주는 변인. ...      1
# 51  종속 변인: 독립변인의 조작결과(操作結果)에 의존하며 이의 효과를 판단하는 준거가 ...      1
# 52  매개 변인: 종속변인에 영향을 주는 독립변인 이외의 변인으로서 연구에 통제되어야 할 변인      1
# 53                양적 변인: 양의 크기를 나타내기 위하여 수량으로 표시돠는 변인      1
# 54                 질적 변인: 변인이 가지고 있는 속성을 수량화할 수 없는 변인      1
# 55                연속 변인: 주어진 범위 내에서는 어떤 값도 가질 수 있는 변인      1
# 56                              비연속 변인: 특정 수치만을 가진 변인      1
# 57  유의 수준(significance level): 보통 α로 표시한다. 95%의 신뢰...      1
# 58  "신뢰 구간(confidence interval, CI): 100(1-α)%의 신뢰...      1
# 59  신뢰 수준(confidence interval level) 또는 신뢰도(reliab...      1
# 60  "p-값(p-value, probability value) 또는 유의 확률(sign...      1
# 61  "임계 값(critical value, threshold value): 검정 통계량...      1
#
# [62 rows x 2 columns]

# %%
math_test = pd.read_csv('./si_manage-test.csv', 'utf8', engine='python')
math_test['topic'] = pd.Series(0, index=math_test.index)
finance_test = pd.read_csv('./si_stat-test.csv', 'utf8', engine='python')
finance_test['topic'] = pd.Series(1, index=finance_test.index)
#테스트 셋 데이터 로드. 출력은 생략합니다!
math = math.T
finance = finance.T
math_test = math_test.T
finance_test = finance_test.T
#tokenize 이슈로 array 형태에 알맞게 조정

# %%
from konlpy.tag import Twitter
pos_tagger = Twitter()

def tokenize(doc):
    # norm, stem은 optional
    return ['/'.join(t) for t in pos_tagger.pos(doc, norm=True, stem=True)]

math_data = [(tokenize((math[row])[0]), (math[row])[1]) for row in math]
finance_data = [(tokenize((finance[row])[0]), (finance[row])[1]) for row in finance]
print(math_data[0])
#수학의 첫번째 문서에 대해 토큰화한 결과를 도출.
#토큰화는 품사태깅 및 및 분절화를 시행합니다. 여기서는 Twitter 라이브러리의 pos 함수를 사용합니다.
# Out:
# (['"/Punctuation', '단순하다/Adjective', '평균/Noun', '분산/Noun', '등/Noun', '의/Josa', '상투/Noun', '적/Suffix', '인/Josa', '분석/Noun', '이외/Noun', '에/Josa', ',/Punctuation', '모집단/Noun', '에서/Josa', '어떻다/Adjective', '인자/Noun', '들/Suffix', '이/Josa', '있다/Adjective', '뽑다/Verb', '보다/Verb', '인자/Noun', '분석/Noun', '과/Josa', ',/Punctuation', '특정/Noun', '표본/Noun', '이/Josa', '어떻다/Adjective', '모집단/Noun', '에/Josa', '속/Noun', '하다/Verb', '(/Punctuation', '원/Noun', '모집단/Noun', '을/Josa', '어떻다/Adjective', '여러/Noun', '집단/Noun', '으로/Josa', '나누다/Verb', '하다/Verb', ')/Punctuation', '판단/Noun', '하다/Verb', '"/Punctuation'], 1)

# %%
math_test_data = [(tokenize((math_test[row])[0]), (math_test[row])[1]) for row in math_test]
finance_test_data = [(tokenize((finance_test[row])[0]), (finance_test[row])[1]) for row in finance_test]
print(finance_test_data[0])
#금융의 첫번째 문서에 대해서도 같은 방법을 취해봅니다.
# Out:
# (['"/Punctuation', '통계학/Noun', '은/Josa', '관찰/Noun', '및/Noun', '조사/Noun', '로/Josa', '얻다/Verb', '수/Noun', '있다/Adjective', '데이터/Noun', '로부터/Noun', ',/Punctuation', '응용/Noun', '수학/Noun', '의/Josa', '기법/Noun', '을/Josa', '이용/Noun', '하다/Verb', '수치/Noun', '상의/Noun', '성질/Noun', ',/Punctuation', '규칙/Noun', '성/Suffix', '또는/Adverb', '불규칙/Noun', '성/Suffix', '을/Josa', '찾아내다/Verb', './Punctuation', '통계/Noun', '적/Suffix', '기법/Noun', '은/Josa', ',/Punctuation', '실험/Noun', '계획/Noun', ',/Punctuation', '데이터/Noun', '의/Josa', '요약/Noun', '이나/Josa', '해석/Noun', '을/Josa', '실시/Noun', '하다/Verb', '있다/Adjective', '어서/Noun', '의/Josa', '"/Punctuation'], 1)

# %%
math_data.extend(finance_data)
math_test_data.extend(finance_test_data)
# 학습을 위해 훈련/테스트 데이터 셋을 합칩니다.
tokens = [t for d in math_data for t in d[0]]
print(len(tokens))
#총 토큰의 갯수를 살펴봅니다.
# Out:
# 6852

# %%
import nltk
text = nltk.Text(tokens, name='Train_Document_Token')
print(len(text.tokens))       #총 토큰의 갯수         
print(len(set(text.tokens)))  #유일한 토큰의 갯수 = (종류)         
pprint(text.vocab().most_common(50)) #상위 50번째 토큰까지 출력해봅니다.

# 관찰 : +, x 등 수학에 관련된 feature들도 높게 출력되지만 대부분의 상위 토큰은 "대다수의 문서에서 똑같이 많이 등장하는" 의미없는 토큰.
# Out:
# 6852
# 1353
# [('하다/Verb', 331),
#  ('의/Josa', 212),
#  ('을/Josa', 180),
#  ('./Punctuation', 176),
#  (',/Punctuation', 166),
#  ('에/Josa', 153),
#  ('경영/Noun', 149),
#  ('(/Punctuation', 134),
#  ('적/Suffix', 130),
#  (')/Punctuation', 121),
#  ('되다/Verb', 99),
#  ('이/Josa', 95),
#  ('있다/Adjective', 95),
#  ('이다/Josa', 81),
#  ('은/Josa', 79),
#  ('것/Noun', 79),
#  ('를/Josa', 75),
#  ('으로/Josa', 68),
#  ('·/Foreign', 68),
#  ('"/Punctuation', 63),
#  ('방침/Noun', 50),
#  ('목적/Noun', 49),
#  ('과/Josa', 44),
#  ('활동/Noun', 43),
#  ('."/Punctuation', 41),
#  ('기업/Noun', 41),
#  ('값/Noun', 39),
#  ('등/Noun', 38),
#  ('가/Josa', 38),
#  ('는/Josa', 36),
#  ('데이터/Noun', 35),
#  ('기능/Noun', 34),
#  ('인/Josa', 31),
#  ('에서/Josa', 31),
#  ('의/Noun', 30),
#  ('그/Noun', 28),
#  ('분석/Noun', 27),
#  ('변인/Noun', 27),
#  ('로/Josa', 26),
#  ('이/Noun', 25),
#  ('사회/Noun', 23),
#  ('조직/Noun', 23),
#  ('위/Noun', 23),
#  ('생산/Noun', 22),
#  ("'/Punctuation", 21),
#  (':/Punctuation', 21),
#  ('평균/Noun', 20),
#  ('관리/Noun', 20),
#  ('경제/Noun', 20),
#  ('또는/Adverb', 20)]

# %%
selected_words = [f[0] for f in text.vocab().most_common(1000)]
selected_words1 = selected_words[1:100]
selected_words2 = selected_words[100:500]
selected_words3 = selected_words[500:1000]
def term_exists_V1(doc):
    return {'exists({})'.format(word): (word in set(doc)) for word in selected_words1}
def term_exists_V2(doc):
    return {'exists({})'.format(word): (word in set(doc)) for word in selected_words2}
def term_exists_V3(doc):
    return {'exists({})'.format(word): (word in set(doc)) for word in selected_words3}

train = [(term_exists_V1(d[0]), d[1]) for d in math_data]
test = [(term_exists_V1(d[0]), d[1]) for d in math_test_data]
# 나이브 베이즈 학습을 시행하기 위해 처리합니다.

# %%
#빈도수 1위~100위를 피쳐로 사용
classifier = nltk.NaiveBayesClassifier.train(train)
print("classification accuracy :" , nltk.classify.accuracy(classifier, test))
classifier.show_most_informative_features(10)
# Out:
# classification accuracy : 0.5757575757575758
# Most Informative Features
#          exists(경영/Noun) = True                0 : 1      =     12.3 : 1.0
#          exists(기본/Noun) = True                0 : 1      =      9.3 : 1.0
#         exists(이라고/Josa) = True                0 : 1      =      9.3 : 1.0
#           exists(관/Noun) = True                0 : 1      =      8.3 : 1.0
#          exists(경제/Noun) = True                0 : 1      =      8.3 : 1.0
#          exists(보다/Verb) = True                0 : 1      =      8.3 : 1.0
#          exists(생산/Noun) = True                0 : 1      =      7.3 : 1.0
#           exists(즉/Noun) = True                0 : 1      =      6.7 : 1.0
#           exists(이/Noun) = True                0 : 1      =      6.5 : 1.0
#         exists(자/Suffix) = True                0 : 1      =      6.3 : 1.0

# %%
#빈도수 100위~500위를 피쳐로 사용
train = [(term_exists_V2(d[0]), d[1]) for d in math_data]
test = [(term_exists_V2(d[0]), d[1]) for d in math_test_data]
classifier = nltk.NaiveBayesClassifier.train(train)
print("classification accuracy :" , nltk.classify.accuracy(classifier, test))
classifier.show_most_informative_features(10)
# Out:
# classification accuracy : 0.5454545454545454
# Most Informative Features
#         exists(으로서/Josa) = True                0 : 1      =      7.3 : 1.0
#         exists(따라서/Noun) = True                0 : 1      =      7.3 : 1.0
#          exists(작업/Noun) = True                0 : 1      =      6.3 : 1.0
#  exists(그리고/Conjunction) = True                0 : 1      =      5.4 : 1.0
#          exists(가지/Noun) = True                0 : 1      =      5.4 : 1.0
#         exists(화/Suffix) = True                0 : 1      =      4.4 : 1.0
#          exists(이란/Josa) = True                0 : 1      =      4.4 : 1.0
#          exists(확대/Noun) = True                0 : 1      =      4.4 : 1.0
#          exists(지식/Noun) = True                0 : 1      =      4.4 : 1.0
#          exists(방법/Noun) = True                0 : 1      =      4.4 : 1.0

# %%
#빈도수 500위~1000위를 피쳐로 사용
train = [(term_exists_V3(d[0]), d[1]) for d in math_data]
test = [(term_exists_V3(d[0]), d[1]) for d in math_test_data]
classifier = nltk.NaiveBayesClassifier.train(train)
print("classification accuracy :" , nltk.classify.accuracy(classifier, test))
classifier.show_most_informative_features(10)

# 하위의 빈도수 단어를 포함할 수록 결과가 좋아진다는 것을 관찰할 수 있습니다.
# 그러나 모든 하위의 빈도수 단어를 포함하면 계속해서 결과가 좋아지는가? 는 생각해볼 문제입니다. 
# 첫번째로, 한두번밖에 등장하지 않았던 단어들도 포함될 여지가 있기 때문이고
# 두번째로, 아래 결과표와 같이 특징을 우리의 학습 데이터에만 잡을 여지가 있기 때문입니다. (2008, 2012, 2013과 같은 feature)
# Out:
# classification accuracy : 0.6666666666666666
# Most Informative Features
#        exists(이라고도/Josa) = True                0 : 1      =      1.5 : 1.0
#           exists(인/Noun) = True                0 : 1      =      1.5 : 1.0
#          exists(보통/Noun) = True                0 : 1      =      1.5 : 1.0
#          exists(만이/Josa) = True                0 : 1      =      1.5 : 1.0
#          exists(표시/Noun) = True                0 : 1      =      1.5 : 1.0
#   exists(어떠하다/Adjective) = True                0 : 1      =      1.5 : 1.0
#          exists(일련/Noun) = True                0 : 1      =      1.5 : 1.0
#          exists(효과/Noun) = True                0 : 1      =      1.5 : 1.0
#           exists(양/Noun) = True                0 : 1      =      1.5 : 1.0
#           exists(비/Noun) = True                0 : 1      =      1.5 : 1.0

# %%
from collections import namedtuple
TaggedDocument = namedtuple('TaggedDocument', 'words tags')
tagged_train_docs = [TaggedDocument(d[0], str(d[1])) for d in math_data]
tagged_test_docs = [TaggedDocument(d[0], str(d[1])) for d in math_test_data]
#doc2vec을 시행해봅니다.

# %%
from gensim.models import doc2vec
#doc_vectorizer = doc2vec.Doc2Vec(size=300, alpha=0.025, min_alpha=0.025, seed=1234)
#doc_vectorizer.build_vocab(tagged_train_docs)
# Train document vectors!
#for epoch in range(10):
#    doc_vectorizer.train(tagged_train_docs)
#    doc_vectorizer.alpha -= 0.002  # decrease the learning rate
#    doc_vectorizer.min_alpha = doc_vectorizer.alpha  # fix the learning rate, no decay
# 참고한 API가 deprecated되어서 새로 작성함.
    
model = doc2vec.Doc2Vec(vector_size=300, window=10, min_count=5, workers=11,alpha=0.025, min_alpha=0.025, epochs=10)
model.build_vocab(tagged_train_docs)
model.train(tagged_train_docs, epochs=model.epochs, total_examples=model.corpus_count)
# epchos를 줄일수록 결과가 좋았음. 왜?
# Out:
# C:\Users\Lee.DESKTOP-116N9I7\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
pprint(model.wv.most_similar('경영/Noun'))
# '집합' 이라는 단어에 대하여 어떤 단어 벡터들이 가장 가까운지 확인해봅니다.
# Out:
# [('이/Noun', 0.999941349029541),
#  ('행위/Noun', 0.9999374151229858),
#  ('적/Suffix', 0.9999352693557739),
#  ('생산/Noun', 0.9999315738677979),
#  ('경제/Noun', 0.9999301433563232),
#  ('단계/Noun', 0.9999276399612427),
#  ('체/Noun', 0.9999248385429382),
#  ('관/Noun', 0.9999244213104248),
#  ('달성/Noun', 0.99991774559021),
#  ('시키다/Verb', 0.9999174475669861)]

# %%
pprint(model.wv.most_similar('통계/Noun'))
# Out:
# [('로/Josa', 0.9999496340751648),
#  ('한/Josa', 0.9999151229858398),
#  ('를/Josa', 0.999914288520813),
#  ('5/Number', 0.9999006390571594),
#  ('를/Noun', 0.9998985528945923),
#  ('연구/Noun', 0.9998960494995117),
#  ('기관/Noun', 0.9998936057090759),
#  ('또는/Adverb', 0.9998908042907715),
#  ('1/Number', 0.9998899698257446),
#  ('측정/Noun', 0.9998863935470581)]

# %%
pprint(model.wv.most_similar('신뢰/Noun'))
# Out:
# [('-/Punctuation', 0.9998186826705933),
#  ('를/Noun', 0.9997967481613159),
#  ('value/Alpha', 0.9997764825820923),
#  ('):/Punctuation', 0.9997742772102356),
#  ('α/Foreign', 0.9997680187225342),
#  ('0/Number', 0.9997585415840149),
#  ('1/Number', 0.9997545480728149),
#  ('유의/Noun', 0.9997506737709045),
#  ('로/Josa', 0.9997413158416748),
#  ('빅/Noun', 0.9997337460517883)]
